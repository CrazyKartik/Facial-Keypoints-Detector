# %% [markdown]
# **Getting the Data**

# %%
from google.colab import files
files.upload()

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c facial-keypoints-detection

# %%
# !unzip \test.zip
# Out:
# Archive:  test.zip
#   inflating: test.csv

# %%
# !unzip \training.zip
# Out:
# Archive:  training.zip
#   inflating: training.csv

# %% [markdown]
# **Importing the Modules**

# %%
import sys

try:
    import DataAugmentation
    import utilities as utils
    import CustomModuleTests as tests
except:
    print(sys.exc_info()[0])

# %%
try:
    tests.checkUtils()
except:
    print(sys.exc_info()[0])
# Out:
# Training Images Shape: (2140, 96, 96, 1)
# Training Keypoints Shape: (2140, 30)

# %%
try:
    #checker object
    aug_chk = tests.ValidateAugmentor()
except:
    print(sys.exc_info()[0])

# %%
try:
    aug_chk.checkFlipAugmentation()
except:
    print(sys.exc_info()[0])

# %%
try:
    aug_chk.checkRotationAugmentation()
except:
    print(sys.exc_info()[0])
# Out:
# Shape of the rotated images array: (4276, 96, 96, 1)
# Shape of the original training images array: (2140, 96, 96, 1)

# %%
try:
    aug_chk.checkBrightnessAugmentation()
except:
    print(sys.exc_info()[0])

# %%
try:
    aug_chk.checkShiftAugmentation()
except:
    print(sys.exc_info()[0])
# Out:
# Shape of the shifted images array: (6350, 96, 96)
# Shape of the original training images array: (2140, 96, 96, 1)

# %%
try:
    aug_chk.checkNoiseAugmentation()
except:
    print(sys.exc_info()[0])
